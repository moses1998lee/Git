# %% [markdown]
# ## Question 1
#
# 1. Given the data table `wage_data` below,
#
# ```python
# ####################
# import pandas as pd
#
# wage_data = pd.DataFrame({'wage': [3.10, 3.24, 3.00, 6.00, 5.30],
#                           'educ': [11.0, 12.0, 11.0, 8.0, 12.0],
#                           'expr': [2.0, 22.0, 2.0, 44.0, 7.0],
#                           'female': [1.0, 1.0, 0.0, 0.0, 0.0],
#                           'married': [0.0, 1.0, 0.0, 0.0, 1.0]})
# ####################
# ```
#
# which of the following code gives the median of variable `wage`? (Ans: D)
#
#     A.
# ```python
# ####################
# wage_summary = wage_data.describe()
# print(wage_summary.loc['wage', 'median'])
# ####################
# ```
#
#     B.
# ```python
# ####################
# wage_summary = wage_data.describe()
# print(wage_summary.loc['median', 'wage'])
# ####################
# ```
#
#     C.
# ```python
# ####################
# wage_summary = wage_data.describe()
# print((wage_summary.loc['wage', 'min'] + wage_summary.loc['wage', 'max']) / 2)
# ####################
# ```
#
#     D.
# ```python
# ####################
# wage_summary = wage_data.describe()
# print((wage_summary.loc['50%', 'wage']))
# ####################
# ```
#
# **Solution:**

# %%
import pandas as pd

wage_data = pd.DataFrame({'wage': [3.10, 3.24, 3.00, 6.00, 5.30],
                          'educ': [11.0, 12.0, 11.0, 8.0, 12.0],
                          'expr': [2.0, 22.0, 2.0, 44.0, 7.0],
                          'female': [1.0, 1.0, 0.0, 0.0, 0.0],
                          'married': [0.0, 1.0, 0.0, 0.0, 1.0]})

wage_summary = wage_data.describe()
display(wage_summary)

print((wage_summary.loc['50%', 'wage']))
# Out:
#            wage       educ       expr    female   married
# count  5.000000   5.000000   5.000000  5.000000  5.000000
# mean   4.128000  10.800000  15.400000  0.400000  0.400000
# std    1.413832   1.643168  17.966636  0.547723  0.547723
# min    3.000000   8.000000   2.000000  0.000000  0.000000
# 25%    3.100000  11.000000   2.000000  0.000000  0.000000
# 50%    3.240000  11.000000   7.000000  0.000000  0.000000
# 75%    5.300000  12.000000  22.000000  1.000000  1.000000
# max    6.000000  12.000000  44.000000  1.000000  1.000000
# 3.24

# %% [markdown]
# 2. For the same dataset `wage_data`, which of the following code segments is correct in printing the correlation between `educ` and `expr`. (Ans: B)
#
#     A.
# ```python
# ####################
# corr_table = wage_data.corr()
# print(corr_table.iloc['educ', 'expr'])
# ####################
# ```
#
#     B.
# ```python
# ####################
# corr_table = wage_data.corr()
# print(corr_table.iloc[1, 2])
# ####################
# ```
#
#     C.
# ```python
# ####################
# corr_table = wage_data.corr()
# print(corr_table.loc[:, 'educ'].loc[:, 'expr'])
# ####################
# ```
#
#     D.
# ```python
# ####################
# corr_table = wage_data.corr()
# print(corr_table.loc[:, 'educ':'expr'])
# ####################
# ```
#
# **Solution:**

# %%
import pandas as pd

wage_data = pd.DataFrame({'wage': [3.10, 3.24, 3.00, 6.00, 5.30],
                          'educ': [11.0, 12.0, 11.0, 8.0, 12.0],
                          'expr': [2.0, 22.0, 2.0, 44.0, 7.0],
                          'female': [1.0, 1.0, 0.0, 0.0, 0.0],
                          'married': [0.0, 1.0, 0.0, 0.0, 1.0]})

corr_table = wage_data.corr()
display(corr_table)

print(corr_table.iloc[1, 2])
# Out:
#              wage      educ      expr    female   married
# wage     1.000000 -0.573787  0.656686 -0.618553  0.091685
# educ    -0.573787  1.000000 -0.741815  0.388889  0.666667
# expr     0.656686 -0.741815  1.000000 -0.172751 -0.045728
# female  -0.618553  0.388889 -0.172751  1.000000  0.166667
# married  0.091685  0.666667 -0.045728  0.166667  1.000000
# -0.7418147590337925

# %% [markdown]
# ---

# %% [markdown]
# ## Question 2
#
# Considering the following dataset on Singapore private house properties.

# %%
import pandas as pd

prop = pd.read_csv('properties.csv')
prop
# Out:
#                        project                   street         type  \
# 0                PARC CLEMATIS            JALAN LEMPENG    Apartment
# 1               ONE PEARL BANK               PEARL BANK    Apartment
# 2               ONE PEARL BANK               PEARL BANK    Apartment
# 3               ONE PEARL BANK               PEARL BANK    Apartment
# 4                    THE CREST  PRINCE CHARLES CRESCENT  Condominium
# ...                        ...                      ...          ...
# 104896              FLORAVILLE              CACTUS ROAD    Apartment
# 104897         EUPHONY GARDENS          JALAN MATA AYER  Condominium
# 104898         SYMPHONY SUITES             YISHUN CLOSE  Condominium
# 104899         SYMPHONY SUITES             YISHUN CLOSE  Condominium
# 104900  SELETAR PARK RESIDENCE             SELETAR ROAD  Condominium
#
#         district segment    tenure  commence      sale  total_price  area  \
# 0              5     OCR  99 years    2019.0  New Sale      2567000  1496
# 1              3     RCR  99 years    2019.0  New Sale      2986000  1281
# 2              3     RCR  99 years    2019.0  New Sale      1835000   700
# 3              3     RCR  99 years    2019.0  New Sale      1924000   840
# 4              3     RCR  99 years    2012.0    Resale      1620000   883
# ...          ...     ...       ...       ...       ...          ...   ...
# 104896        28     OCR  freehold       NaN  New Sale       910000   818
# 104897        27     OCR  99 years    1998.0    Resale       739998  1044
# 104898        27     OCR  99 years    2014.0  New Sale       875000   797
# 104899        27     OCR  99 years    2014.0  New Sale       759000   689
# 104900        28     OCR  99 years    2011.0    Resale      1060000   872
#
#            level  unit_price      date
# 0       11 to 15        1716  Dec-2021
# 1       16 to 20        2331  Dec-2021
# 2       21 to 25        2623  Dec-2021
# 3       06 to 10        2292  Dec-2021
# 4       11 to 15        1835  Dec-2021
# ...          ...         ...       ...
# 104896  01 to 05        1112  Jan-2017
# 104897  01 to 05         709  Jan-2017
# 104898  11 to 15        1099  Jan-2017
# 104899  11 to 15        1102  Jan-2017
# 104900  01 to 05        1216  Jan-2017
#
# [104901 rows x 13 columns]

# %% [markdown]
# Details of the variables are given below:
# - `project`: The name of the property project.
# - `street`: The street name of the property.
# - `type`: The type of the property: apartment or condominium.
# - `district`: Location of the property, given as the district code of Singapore, details can be found [here](https://www.mingproperty.sg/singapore-district-code/).
# - `segment`: Location of the property, given as the region segment of Singapore: Core Central Region (CCR), Rest of Central Region (RCR), or the Outside Central Region (OCR).
# - `tenure`: The tenure type of the property: 99 years or freehold.
# - `commence`: The commencing year of the property.
# - `sale`: The sales type of the property: new sale or resale.
# - `total_price`: The total price (in Singapore Dollars) of the property.
# - `area`: The area of the property in square feet.
# - `level`: The levels of the condos.
# - `unit_price`: The per square feet price of the property (in Singapore Dollars).
# - `date`: The date of the transaction.
#
# 1. What is the average unit price of all **new sale freehold condos smaller than 2000 square feet**?
#
# **Solution:**

# %%
print(prop['sale'].unique())
print(prop['tenure'].unique())
print(prop['type'].unique())
# Out:
# ['New Sale' 'Resale' 'Sub Sale']
# ['99 years' 'freehold']
# ['Apartment' 'Condominium']

# %%
cond1 = prop['sale'] == 'New Sale'
cond2 = prop['tenure'] == 'freehold'
cond3 = prop['type'] == 'Condominium'
cond4 = prop['area'] < 2000

subset = prop.loc[cond1 & cond2 & cond3 & cond4]
subset
# Out:
#                         project              street         type  district  \
# 20631   VILLAGE @ PASIR PANJANG  PASIR PANJANG ROAD  Condominium         5
# 20806              LEEDON GREEN      LEEDON HEIGHTS  Condominium        10
# 20808              LEEDON GREEN      LEEDON HEIGHTS  Condominium        10
# 20809              LEEDON GREEN      LEEDON HEIGHTS  Condominium        10
# 20822                ROYALGREEN     ANAMALAI AVENUE  Condominium        10
# ...                         ...                 ...          ...       ...
# 100390        THE CREEK @ BUKIT       TOH TUCK ROAD  Condominium        21
# 100394        THE CREEK @ BUKIT       TOH TUCK ROAD  Condominium        21
# 100406        THE CREEK @ BUKIT       TOH TUCK ROAD  Condominium        21
# 100446        THE CREEK @ BUKIT       TOH TUCK ROAD  Condominium        21
# 100455        THE CREEK @ BUKIT       TOH TUCK ROAD  Condominium        21
#
#        segment    tenure  commence      sale  total_price  area     level  \
# 20631      RCR  freehold       NaN  New Sale      1700000  1410  01 to 05
# 20806      CCR  freehold       NaN  New Sale      2017000   710  11 to 15
# 20808      CCR  freehold       NaN  New Sale      1839000   700  01 to 05
# 20809      CCR  freehold       NaN  New Sale      1424000   538  01 to 05
# 20822      CCR  freehold       NaN  New Sale      3701200  1259  01 to 05
# ...        ...       ...       ...       ...          ...   ...       ...
# 100390     RCR  freehold       NaN  New Sale      1645000  1206  01 to 05
# 100394     RCR  freehold       NaN  New Sale      1610129   936  01 to 05
# 100406     RCR  freehold       NaN  New Sale      1500000   969  01 to 05
# 100446     RCR  freehold       NaN  New Sale      1246000   753  01 to 05
# 100455     RCR  freehold       NaN  New Sale      1225075   753  01 to 05
#
#         unit_price      date
# 20631         1206  Feb-2017
# 20806         2839  Dec-2021
# 20808         2628  Dec-2021
# 20809         2646  Dec-2021
# 20822         2939  Dec-2021
# ...            ...       ...
# 100390        1365  Feb-2017
# 100394        1719  Feb-2017
# 100406        1548  Feb-2017
# 100446        1654  Jan-2017
# 100455        1626  Jan-2017
#
# [2418 rows x 13 columns]

# %%
subset['unit_price'].mean()
# Out:
# 2290.2696443341606

# %% [markdown]
# 2. Considering all **new sale freehold condos smaller than 2000 square feet**, use proper data visualization method to show how prices of condos in different regions, CCR, RCR, or OCR, are affected by their areas.
#
# **Solution:**

# %%
import matplotlib.pyplot as plt

ccr = subset[subset['segment'] == 'CCR']
rcr = subset[subset['segment'] == 'RCR']
ocr = subset[subset['segment'] == 'OCR']

plt.figure(figsize=(5,3))
plt.scatter(ccr['area'], ccr['total_price'], alpha=0.4, label='CCR')
plt.scatter(rcr['area'], rcr['total_price'], alpha=0.4, label='RCR')
plt.scatter(ocr['area'], ocr['total_price'], alpha=0.4, label='OCR')
plt.title("Price vs Area for different Segments", fontsize=10, fontweight="bold")
plt.xlabel('Area (sqft)', fontsize=10)
plt.ylabel('Price (S$)', fontsize=10)
plt.legend(fontsize=10)
plt.grid()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Question 3
#
# The prices of fifteen stocks between September 2021 and August 2021 are included in the data file 'stocks.csv'.

# %%
import pandas as pd

stocks = pd.read_csv('stocks.csv')
stocks
# Out:
#             JPM         XOM         CRM        AMZN        TSLA       TWTR  \
# 0    155.282562   51.443314  268.320007  173.949997  244.696671  65.550003
# 1    156.002014   52.696636  264.149994  173.156006  244.130005  64.599998
# 2    155.058945   52.495712  267.079987  173.902496  244.523331  64.660004
# 3    154.786728   52.189560  265.209991  175.464493  250.973328  64.980003
# 4    154.096451   51.711193  262.619995  176.274994  251.289993  62.270000
# ..          ...         ...         ...         ...         ...        ...
# 247  118.550003   99.089996  173.910004  137.279999  296.070007  41.049999
# 248  114.669998   97.870003  165.229996  130.750000  288.089996  40.459999
# 249  114.389999  100.120003  160.210007  129.789993  284.820007  40.040001
# 250  114.410004   96.309998  159.669998  128.729996  277.700012  39.320000
# 251  113.730003   95.589996  156.119995  126.769997  275.609985  38.750000
#
#            AAPL       ORCL        GOOG          ZM         MCD         NKE  \
# 0    151.660172  88.562317  145.841995  290.859985  232.953491  163.017487
# 1    152.793808  88.414650  144.218994  295.089996  234.635956  162.135849
# 2    153.440186  88.611557  144.774994  298.290009  233.608871  161.759384
# 3    155.816879  87.351303  145.518997  299.959991  231.036270  161.115479
# 4    154.245682  88.089737  144.883499  293.600006  233.413239  159.203583
# ..          ...        ...         ...         ...         ...         ...
# 247  170.029999  76.889999  117.699997   85.720001  261.130615  112.895729
# 248  163.619995  74.650002  111.300003   81.410004  255.551178  107.969872
# 249  161.380005  74.190002  110.339996   81.000000  254.268188  107.571014
# 250  158.910004  74.139999  109.910004   81.419998  252.110016  107.551079
# 251  157.220001  74.150002  109.150002   80.400002  252.279999  106.145111
#
#            SBUX          T         KO
# 0    114.887390  18.961119  54.612629
# 1    114.809143  19.274929  54.689697
# 2    114.633080  19.219139  54.651161
# 3    113.263618  19.121511  53.630005
# 4    115.464531  19.247034  54.352516
# ..          ...        ...        ...
# 247   87.389999  18.090000  64.201912
# 248   84.059998  17.889999  62.653210
# 249   84.120003  17.780001  62.275959
# 250   83.410004  17.820000  61.700157
# 251   84.070000  17.540001  61.263340
#
# [252 rows x 15 columns]

# %% [markdown]
# 1. Visualize the price trend of ONE select stock.
#
# **Solution**:

# %%
import matplotlib.pyplot as plt

name = 'ZM'
stock = stocks[name]
n = len(stock)

xdata = range(1, n+1)
plt.figure(figsize=(4,3))
plt.plot(xdata, stock, linewidth=1)
plt.title("Daily Price for {}".format(name), fontsize=10, fontweight="bold")
plt.xlabel('Day', fontsize=10)
plt.ylabel('Price', fontsize=10)
plt.grid()
plt.show()

# %% [markdown]
# 2. Calculate the daily return rate in percentage of each stock, and visualize the trend of the return rate of ONE stock.
#
# *Hint*: you could use the `stocks.pct_change()` method to calculate the rate of change between rows.
#
# **Solution**:

# %%
rors = stocks.pct_change() * 100
rors
# Out:
#           JPM       XOM       CRM      AMZN      TSLA      TWTR      AAPL  \
# 0         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1    0.463318  2.436318 -1.554119 -0.456448 -0.231579 -1.449282  0.747485
# 2   -0.604524 -0.381284  1.109216  0.431109  0.161113  0.092887  0.423039
# 3   -0.175557 -0.583195 -0.700163  0.898202  2.637784  0.494896  1.548938
# 4   -0.445954 -0.916595 -0.976583  0.461917  0.126175 -4.170518 -1.008362
# ..        ...       ...       ...       ...       ...       ...       ...
# 247  2.374784  0.517341 -3.388696  2.600894 -0.345568  0.637407  1.492270
# 248 -3.272885 -1.231198 -4.991092 -4.756701 -2.695312 -1.437272 -3.769925
# 249 -0.244178  2.298968 -3.038183 -0.734231 -1.135058 -1.038058 -1.369020
# 250  0.017488 -3.805439 -0.337063 -0.816702 -2.499823 -1.798205 -1.530550
# 251 -0.594354 -0.747587 -2.223338 -1.522566 -0.752620 -1.449643 -1.063497
#
#          ORCL      GOOG        ZM       MCD       NKE      SBUX         T  \
# 0         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1   -0.166738 -1.112849  1.454312  0.722232 -0.540824 -0.068108  1.655020
# 2    0.222709  0.385525  1.084419 -0.437735 -0.232191 -0.153353 -0.289443
# 3   -1.422223  0.513903  0.559852 -1.101243 -0.398064 -1.194647 -0.507971
# 4    0.845361 -0.436711 -2.120278  1.028829 -1.186662  1.943177  0.656447
# ..        ...       ...       ...       ...       ...       ...       ...
# 247  0.945256  2.615519  2.523622  0.651687  1.624631  1.557230  0.444197
# 248 -2.913250 -5.437548 -5.027995 -2.136646 -4.363192 -3.810507 -1.105587
# 249 -0.616208 -0.862540 -0.503628 -0.502048 -0.369415  0.071384 -0.614861
# 250 -0.067399 -0.389698  0.518516 -0.848778 -0.018533 -0.844031  0.224966
# 251  0.013491 -0.691477 -1.252759  0.067424 -1.307256  0.791267 -1.571261
#
#            KO
# 0         NaN
# 1    0.141118
# 2   -0.070463
# 3   -1.868499
# 4    1.347215
# ..        ...
# 247  0.481657
# 248 -2.412237
# 249 -0.602125
# 250 -0.924597
# 251 -0.707968
#
# [252 rows x 15 columns]

# %%
import matplotlib.pyplot as plt

name = 'GOOG'
ror = rors[name]
n = len(ror)

xdata = range(1, n+1)
plt.figure(figsize=(8,3))
plt.plot(xdata, ror, linewidth=1)
plt.title("Daily Rate of Return for {}".format(name), fontsize=10, fontweight="bold")
plt.xlabel('Day', fontsize=10)
plt.ylabel('Rate of return', fontsize=10)
plt.grid()
plt.show()

# %% [markdown]
# 3. What are the average values and variances of the daily return rates of these stocks?
#
# **Solution**:

# %%
rors.mean()
# Out:
# JPM    -0.109114
# XOM     0.269631
# CRM    -0.177234
# AMZN   -0.087132
# TSLA    0.127347
# TWTR   -0.153277
# AAPL    0.033049
# ORCL   -0.049873
# GOOG   -0.092837
# ZM     -0.434619
# MCD     0.038536
# NKE    -0.146929
# SBUX   -0.102772
# T      -0.017299
# KO      0.052805
# dtype: float64

# %%
rors.var()
# Out:
# JPM      2.985214
# XOM      4.498280
# CRM      7.663458
# AMZN     7.770078
# TSLA    15.999455
# TWTR    11.585269
# AAPL     3.750804
# ORCL     4.292733
# GOOG     4.537840
# ZM      15.161633
# MCD      1.359998
# NKE      4.771743
# SBUX     4.347708
# T        2.748544
# KO       1.397867
# dtype: float64

# %% [markdown]
# 4. Visualize the risk-return trade-off, where the x-data are the standard deviations of return rates, and the y-data indicate the average return rates.
#
# **Solution**:

# %%
import matplotlib.pyplot as plt

std = rors.std()
mean = rors.mean()

plt.figure(figsize=(4,3))
plt.scatter(std, mean, alpha=0.4)
plt.title("Mean Return vs Risk", fontsize=10, fontweight="bold")
plt.xlabel('Risk (standard deviation)', fontsize=10)
plt.ylabel('Mean Return', fontsize=10)
plt.grid()
plt.show()

# %% [markdown]
# Using the visualization from (4), add bubble sizes to indicate the average prices of these stocks.
#
# **Solution:**

# %%
import matplotlib.pyplot as plt

std = rors.std()
mean = rors.mean()
price = stocks.mean()

plt.figure(figsize=(4,3))
plt.scatter(std, mean, s=price, alpha=0.4)
plt.title("Mean Return vs Risk", fontsize=10, fontweight="bold")
plt.xlabel('Risk (standard deviation)', fontsize=10)
plt.ylabel('Mean Return', fontsize=10)
plt.grid()
plt.show()

# %% [markdown]
# 5. Calculate the correlations between these stock prices.
#
# **Solution**:

# %%
stocks.corr()
# Out:
#            JPM       XOM       CRM      AMZN      TSLA      TWTR      AAPL  \
# JPM   1.000000 -0.873032  0.917046  0.867053  0.516792  0.528087  0.165678
# XOM  -0.873032  1.000000 -0.889664 -0.816485 -0.356151 -0.634308 -0.032621
# CRM   0.917046 -0.889664  1.000000  0.872018  0.524129  0.656959  0.042884
# AMZN  0.867053 -0.816485  0.872018  1.000000  0.666453  0.519377  0.419199
# TSLA  0.516792 -0.356151  0.524129  0.666453  1.000000  0.066236  0.651967
# TWTR  0.528087 -0.634308  0.656959  0.519377  0.066236  1.000000 -0.305328
# AAPL  0.165678 -0.032621  0.042884  0.419199  0.651967 -0.305328  1.000000
# ORCL  0.878423 -0.843199  0.933862  0.893054  0.604226  0.624257  0.229457
# GOOG  0.897699 -0.843315  0.885101  0.951212  0.650422  0.444618  0.385735
# ZM    0.841065 -0.896337  0.923460  0.744512  0.249872  0.806824 -0.201341
# MCD  -0.075528  0.149635 -0.109037  0.014229  0.364516 -0.249975  0.581618
# NKE   0.943297 -0.889240  0.927154  0.905571  0.620514  0.509859  0.260511
# SBUX  0.903269 -0.915121  0.931436  0.876936  0.464150  0.599551  0.180867
# T    -0.417488  0.376545 -0.446185 -0.628674 -0.574169 -0.006054 -0.556551
# KO   -0.814991  0.875601 -0.880184 -0.698281 -0.200573 -0.633890  0.219509
#
#           ORCL      GOOG        ZM       MCD       NKE      SBUX         T  \
# JPM   0.878423  0.897699  0.841065 -0.075528  0.943297  0.903269 -0.417488
# XOM  -0.843199 -0.843315 -0.896337  0.149635 -0.889240 -0.915121  0.376545
# CRM   0.933862  0.885101  0.923460 -0.109037  0.927154  0.931436 -0.446185
# AMZN  0.893054  0.951212  0.744512  0.014229  0.905571  0.876936 -0.628674
# TSLA  0.604226  0.650422  0.249872  0.364516  0.620514  0.464150 -0.574169
# TWTR  0.624257  0.444618  0.806824 -0.249975  0.509859  0.599551 -0.006054
# AAPL  0.229457  0.385735 -0.201341  0.581618  0.260511  0.180867 -0.556551
# ORCL  1.000000  0.873380  0.829996  0.058696  0.897469  0.911988 -0.521235
# GOOG  0.873380  1.000000  0.747094 -0.034958  0.933423  0.868728 -0.594810
# ZM    0.829996  0.747094  1.000000 -0.229764  0.826268  0.891134 -0.200556
# MCD   0.058696 -0.034958 -0.229764  1.000000  0.003642  0.048501 -0.038846
# NKE   0.897469  0.933423  0.826268  0.003642  1.000000  0.923663 -0.507033
# SBUX  0.911988  0.868728  0.891134  0.048501  0.923663  1.000000 -0.459382
# T    -0.521235 -0.594810 -0.200556 -0.038846 -0.507033 -0.459382  1.000000
# KO   -0.771118 -0.718101 -0.895204  0.368257 -0.788057 -0.847691  0.365077
#
#             KO
# JPM  -0.814991
# XOM   0.875601
# CRM  -0.880184
# AMZN -0.698281
# TSLA -0.200573
# TWTR -0.633890
# AAPL  0.219509
# ORCL -0.771118
# GOOG -0.718101
# ZM   -0.895204
# MCD   0.368257
# NKE  -0.788057
# SBUX -0.847691
# T     0.365077
# KO    1.000000

# %% [markdown]
# 6. Visualize the histogram of the return rate of ONE selected stock.
#
# **Solution**:

# %%
import matplotlib.pyplot as plt

name = 'TSLA'
ror = rors[name]

plt.figure(figsize=(4,3))
plt.hist(ror, bins=30, color='r', alpha=0.5)
plt.title("Histogram for Rate of Return", fontsize=10, fontweight="bold")
plt.xlabel('Rate of Return (%)', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.grid()
plt.show()

# %% [markdown]
# 7. Moving average is a commonly used tool in analyzing stock markets. Pandas also provides a method called `rolling()` for calculating the moving average of a number of rows. For example, `stock.rolling(5).mean()` calculates the 5-day moving averages of the given stocks. Visualize the trend of the $k$-day moving average of ONE selected stock. You could explore how the trend is affected by different values of $k$.
#
# **Solution**:

# %%
k = 4

stocks.rolling(k).mean()
# Out:
#             JPM        XOM         CRM        AMZN        TSLA       TWTR  \
# 0           NaN        NaN         NaN         NaN         NaN        NaN
# 1           NaN        NaN         NaN         NaN         NaN        NaN
# 2           NaN        NaN         NaN         NaN         NaN        NaN
# 3    155.282562  52.206306  266.189995  174.118248  246.080833  64.947502
# 4    154.986034  52.273275  264.764992  174.699497  247.729164  64.127501
# ..          ...        ...         ...         ...         ...        ...
# 247  116.635000  97.420000  176.724998  134.480000  294.883339  41.177500
# 248  116.135000  98.385000  173.787498  133.862499  294.427505  40.540000
# 249  115.852501  98.915001  169.840000  132.904999  291.519173  40.585000
# 250  115.505001  98.347500  164.755001  131.637497  286.670006  40.217500
# 251  114.300001  97.472500  160.307499  129.009996  281.555000  39.642500
#
#            AAPL       ORCL        GOOG          ZM         MCD         NKE  \
# 0           NaN        NaN         NaN         NaN         NaN         NaN
# 1           NaN        NaN         NaN         NaN         NaN         NaN
# 2           NaN        NaN         NaN         NaN         NaN         NaN
# 3    153.427761  88.234957  145.088745  296.049995  233.058647  162.007050
# 4    154.074139  88.116812  144.849121  296.735001  233.173584  161.053574
# ..          ...        ...         ...         ...         ...         ...
# 247  168.090000  76.482500  115.559998   87.022501  260.302666  111.093403
# 248  167.102497  76.030001  114.617498   83.015001  258.810829  110.579878
# 249  165.639999  75.475000  113.509998   82.935001  257.597466  109.881882
# 250  163.485001  74.967501  112.312500   82.387501  255.764999  108.996923
# 251  160.282501  74.282501  110.175001   81.057501  253.552345  107.309269
#
#            SBUX          T         KO
# 0           NaN        NaN        NaN
# 1           NaN        NaN        NaN
# 2           NaN        NaN        NaN
# 3    114.398308  19.144175  54.395873
# 4    114.542593  19.215653  54.330845
# ..          ...        ...        ...
# 247   85.770000  18.072500  63.909050
# 248   85.547501  18.012500  63.638523
# 249   85.405001  17.942500  63.256310
# 250   84.745001  17.895000  62.707809
# 251   83.915001  17.757500  61.973166
#
# [252 rows x 15 columns]

# %%
import matplotlib.pyplot as plt

name = 'SBUX'
xdata = range(1, n+1)

plt.figure(figsize=(6,4))
plt.plot(xdata, stocks[name], linewidth=1, color='b', alpha=0.8, label='Daily price trend')

days = [5, 25, 40, 60, 90, 120]
for k in days:
    ma = stocks.rolling(k).mean()
    plt.plot(xdata, ma[name], linewidth=1, label='{0}-day moving avg.'.format(k))

plt.title("Moving Average Stock Price for {}".format(name), fontsize=10, fontweight="bold")
plt.xlabel('Day', fontsize=10)
plt.ylabel('Price', fontsize=10)
plt.legend()
plt.grid()
plt.show()
