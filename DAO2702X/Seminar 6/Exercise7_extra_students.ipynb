# %% [markdown]
# ## Question 1
#
# 1. Refer back to Question **1.1** of **Exercise 7**. Write code to modify the dataframe with the following:
#    - values in the `educ` and `expr` columns to be integer
#
# **Solution:**

# %%
import pandas as pd

wage_data = pd.DataFrame({'wage': [3.10, 3.24, 3.00, 6.00, 5.30],
                          'educ': [11.0, 12.0, 11.0, 8.0, 12.0],
                          'expr': [2.0, 22.0, 2.0, 44.0, 7.0],
                          'female': [1.0, 1.0, 0.0, 0.0, 0.0],
                          'married': [0.0, 1.0, 0.0, 0.0, 1.0]})

wage_data
# Out:
#    wage  educ  expr  female  married
# 0  3.10  11.0   2.0     1.0      0.0
# 1  3.24  12.0  22.0     1.0      1.0
# 2  3.00  11.0   2.0     0.0      0.0
# 3  6.00   8.0  44.0     0.0      0.0
# 4  5.30  12.0   7.0     0.0      1.0

# %% [markdown]
# 2. Modify your dataframe from (1) with the following:
#    - values in the `female` and `married` columns to be boolean
#
# **Solution:**

# %% [markdown]
# 3. Modify your dataframe from (2) with the following:
#    - add a new column `average_years` as the average number of years in education and experience
#
# **Solution:**

# %% [markdown]
# 4. The company has decided to provide employees whose `average_years` are below 10 or whose wage are below 4 with support for further studies. Using your dataframe from (3), write code to add another column `further_studies` with boolean values that indicate if the employee will be given support for further studies.
#
# **Solution:**

# %% [markdown]
# 5. Using the dataframe's `loc` method, modify your dataframe from (4) with the following by adding a new column `wage_category` with 3 possible values:
#    - "low" if wage is less than 4.0
#    - "mid" if wage is at least 4.0 and less than 6.0
#    - "high" if wage is at least 6.0
#
# **Solution:**

# %% [markdown]
# ---

# %% [markdown]
# ## Question 2
#
# 1. Refer back to Question **1.2** of **Exercise 7**. Write code to print each attribute and its smallest correlation with another attribute on every separate line.
#
# **Solution:**

# %%
import pandas as pd

wage_data = pd.DataFrame({'wage': [3.10, 3.24, 3.00, 6.00, 5.30],
                          'educ': [11.0, 12.0, 11.0, 8.0, 12.0],
                          'expr': [2.0, 22.0, 2.0, 44.0, 7.0],
                          'female': [1.0, 1.0, 0.0, 0.0, 0.0],
                          'married': [0.0, 1.0, 0.0, 0.0, 1.0]})

corr_table = wage_data.corr()

corr_table
# Out:
#              wage      educ      expr    female   married
# wage     1.000000 -0.573787  0.656686 -0.618553  0.091685
# educ    -0.573787  1.000000 -0.741815  0.388889  0.666667
# expr     0.656686 -0.741815  1.000000 -0.172751 -0.045728
# female  -0.618553  0.388889 -0.172751  1.000000  0.166667
# married  0.091685  0.666667 -0.045728  0.166667  1.000000

# %% [markdown]
# 2. Refer back to Question **1.2** of **Exercise 7**. Write code to print each attribute and its largest correlation with another attribute on every separate line.
#
# **Solution:**

# %% [markdown]
# 3. Refer back to (1). Write code to print each attribute and the other attribute that it has the smallest correlation with, on every separate line.
#
# **Solution:**

# %% [markdown]
# ---

# %% [markdown]
# ## Question 3
#
# 1. Refer back to **Question 3.2 of Exercise 7**. Plot the histogram for the percentage returns averaged across all stocks for each day.
#
# **Solution:**

# %%
import pandas as pd

stocks = pd.read_csv('stocks.csv')
stocks
# Out:
#             JPM         XOM         CRM        AMZN        TSLA       TWTR  \
# 0    155.282562   51.443314  268.320007  173.949997  244.696671  65.550003
# 1    156.002014   52.696636  264.149994  173.156006  244.130005  64.599998
# 2    155.058945   52.495712  267.079987  173.902496  244.523331  64.660004
# 3    154.786728   52.189560  265.209991  175.464493  250.973328  64.980003
# 4    154.096451   51.711193  262.619995  176.274994  251.289993  62.270000
# ..          ...         ...         ...         ...         ...        ...
# 247  118.550003   99.089996  173.910004  137.279999  296.070007  41.049999
# 248  114.669998   97.870003  165.229996  130.750000  288.089996  40.459999
# 249  114.389999  100.120003  160.210007  129.789993  284.820007  40.040001
# 250  114.410004   96.309998  159.669998  128.729996  277.700012  39.320000
# 251  113.730003   95.589996  156.119995  126.769997  275.609985  38.750000
#
# ...

# %%
rors = stocks.pct_change() * 100
rors
# Out:
#           JPM       XOM       CRM      AMZN      TSLA      TWTR      AAPL  \
# 0         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1    0.463318  2.436318 -1.554119 -0.456448 -0.231579 -1.449282  0.747485
# 2   -0.604524 -0.381284  1.109216  0.431109  0.161113  0.092887  0.423039
# 3   -0.175557 -0.583195 -0.700163  0.898202  2.637784  0.494896  1.548938
# 4   -0.445954 -0.916595 -0.976583  0.461917  0.126175 -4.170518 -1.008362
# ..        ...       ...       ...       ...       ...       ...       ...
# 247  2.374784  0.517341 -3.388696  2.600894 -0.345568  0.637407  1.492270
# 248 -3.272885 -1.231198 -4.991092 -4.756701 -2.695312 -1.437272 -3.769925
# 249 -0.244178  2.298968 -3.038183 -0.734231 -1.135058 -1.038058 -1.369020
# 250  0.017488 -3.805439 -0.337063 -0.816702 -2.499823 -1.798205 -1.530550
# 251 -0.594354 -0.747587 -2.223338 -1.522566 -0.752620 -1.449643 -1.063497
#
#          ORCL      GOOG        ZM       MCD       NKE      SBUX         T  \
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Refer back to **Question 3.2 of Exercise 7**. Plot the histogram for the largest difference of any two stock returns for each day.
#
# **Solution:**

# %%
import matplotlib.pyplot as plt
